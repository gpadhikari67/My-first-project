# %% [markdown]
# # Gravitation
#
# ## Newton's Law of gravitation
#
# ### Statement:
# The gravitational force of attraction betweem two mass is directly propertional to the product of its mass and inversely proportional to the squre of the distance from their centre.
# #### Let $ m_1 $ and $ m_2 $ be the two mass seperated by distance $r$ from their centre.
#    $F$ = $G\frac{m_1m_2}{r^2}$
#
#    ![image.png](attachment:image.png)

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-d2c27f24e9b5> in <module>
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 3 r= np.arrange(1,100,1)# in meter
#       4 m1=100 # in kg
#       5 m2=100 # in kg
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\__init__.py in __getattr__(attr)
#     218             else:
#     219                 raise AttributeError("module {!r} has no attribute "
# --> 220                                      "{!r}".format(__name__, attr))
#     221
#     222         def __dir__():
#
# AttributeError: module 'numpy' has no attribute 'arrange'

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

r= np.linspace(1,100,1)# in meter 
m1=100 # in kg
m2=100 # in kg
G= 6.67*10**-11 # Nm^2/kg^2
F= G*m1*m2/r**2
plt.plot(r,F)
